# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
blobs = pd.read_csv('cluster_blobs.csv')
print(blobs.head())
sns.scatterplot(data=blobs,x='X1',y='X2')
# Out:
#          X1        X2
# 0  4.645333  6.822294
# 1  4.784032  6.422883
# 2 -5.851786  5.774331
# 3 -7.459592  6.456415
# 4  4.918911  6.961479
# <Axes: xlabel='X1', ylabel='X2'>

# %%
moons = pd.read_csv('cluster_moons.csv')
print(moons.head())
sns.scatterplot(data=moons,x='X1',y='X2')
# Out:
#          X1        X2
# 0  0.674362 -0.444625
# 1  1.547129 -0.239796
# 2  1.601930 -0.230792
# 3  0.014563  0.449752
# 4  1.503476 -0.389164
# <Axes: xlabel='X1', ylabel='X2'>

# %%
circles = pd.read_csv('cluster_circles.csv')
print(circles.head())
sns.scatterplot(data=circles,x='X1',y='X2')
# Out:
#          X1        X2
# 0 -0.348677  0.010157
# 1 -0.176587 -0.954283
# 2  0.301703 -0.113045
# 3 -0.782889 -0.719468
# 4 -0.733280 -0.757354
# <Axes: xlabel='X1', ylabel='X2'>

# %%
def display_categories(model,data):
    labels = model.fit_predict(data)
    sns.scatterplot(data=data,x='X1',y='X2',hue=labels,palette='Set1')

# %%
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN

# %%
model1 = KMeans(n_clusters = 3)
display_categories(model1,blobs)
# Out:
# c:\Users\arind\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
model2 = DBSCAN()
display_categories(model2,blobs)

# %%
model = KMeans(n_clusters = 2)
display_categories(model,moons)
# Out:
# c:\Users\arind\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
model2 = DBSCAN(eps=0.15)
display_categories(model2,moons)

# %%
model = KMeans(n_clusters = 2)
display_categories(model,circles)
# Out:
# c:\Users\arind\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
model2 = DBSCAN(eps=0.15)
display_categories(model2,circles)
